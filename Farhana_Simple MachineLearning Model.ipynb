# %%
import pandas as pd # For loading csv file data to numpy array
import numpy as np # For using data as array
import matplotlib.pyplot as plt # For plotting graph(x,y)
from datetime import datetime
print('----------------------Simple Linear Regression-----------------')
print('Name: Farhana Khatoon Abdul Rashid')
print('Roll No.21')
print('College name: Vivek College of Commerce')
print('M.sc(I.T)[Sem 3]')
now = datetime.now()
# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("Date and Time =", dt_string)	
#To import dataset
data=pd.read_csv('Advertising_Budget.csv')
data.head() #To show data

x=data['Impressions'] # Independent variable or predictor.
y=data['Budget'] # Dependent variable or outcome.

def linear_regression(x, y):  
#simple linear regression equation is: Y = Β0 + Β1X
   N=len(x)
   x_mean=x.mean() # Mean of x value
   y_mean=y.mean() # Mean of y value
   #To find B0 and B1 value using formula
   B1_num = ((x - x_mean) * (y - y_mean)).sum()
   B1_den = ((x - x_mean)**2).sum()
   B1 = B1_num / B1_den # B1
   B0 = y_mean - (B1*x_mean) # B0
   print('B0: ',B0) ## Β0 – is a constant (shows the value of Y when the value of X=0)
   print('B1: ',B1) ## Β1 – the regression coefficient (shows how much Y changes for each unit change in X)
   reg_line = 'y = {} + {}β'.format(B0, round(B1, 3)) # To show Regression Line using y=B0+B1X format
   return (B0, B1, reg_line)

# To find correlation coefficient using formula
N = len(x)
num = (N * (x*y).sum()) - (x.sum() * y.sum())
den = np.sqrt((N * (x**2).sum() - x.sum()**2) * (N * (y**2).sum() - y.sum()**2))
R = num / den # Correlation coefficient

# Applying these functions to our data, we can print out the results:
B0, B1, reg_line=linear_regression(x,y)
print('"Regression Line:" ', reg_line)
print('"Correlation Coef.": ', R)
print('"Goodness of Fit": ', R**2)

# Plotting the Regression Line
plt.figure(figsize=(15,5)) # size of figure
plt.scatter(x, y, s=300, linewidths=1, edgecolor='black')
# To show description about SLR figure
text = '''X Mean: ${} (in millions)  
Y Mean: ${} (in Million US$)
Correlation Coef.: {}
Goodness of Fit: {}
y = {} + {}X'''.format(round(x.mean(), 2), 
                       round(y.mean(), 2), 
                       round(R, 4), 
                       round(R**2, 4),
                       round(B0, 3),
                       round(B1, 3))
plt.text(x=80, y=13, s=text, fontsize=12, bbox={'facecolor': 'grey', 'alpha': 0.6, 'pad': 15}) #To give text description format
plt.title('Advertising_Budget')
plt.xlabel('Budget', fontsize=13)
plt.ylabel('Impressions(No.of viewers)', fontsize=13)
plt.plot(x, B0 + B1*x, c = 'g', linewidth=5, alpha=.5, solid_capstyle='round') # For plottng linear line
plt.scatter(x=x.mean(), y=y.mean(), marker='*', s=10**2.5, c='r') # average point
# Out:
# ----------------------Simple Linear Regression-----------------
# Name: Farhana Khatoon Abdul Rashid
# Roll No.21
# College name: Vivek College of Commerce
# M.sc(I.T)[Sem 3]
# Date and Time = 19/11/2022 14:42:05
# B0:  5.656010401575564
# B1:  1.0779286674122301
# "Regression Line:"  y = 5.656010401575564 + 1.078β
# "Correlation Coef.":  0.6398706128862057
# "Goodness of Fit":  0.40943440123536856

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.1-cp310-cp310-win_amd64.whl (10.4 MB)
#      --------------------------------------- 10.4/10.4 MB 11.1 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
#      ------------------------------------- 498.1/498.1 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.23.4-cp310-cp310-win_amd64.whl (14.6 MB)
#      --------------------------------------- 14.6/14.6 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.4 pandas-1.5.1 pytz-2022.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (1.23.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.2-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ------------------------------------- 965.4/965.4 kB 10.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp310-cp310-win_amd64.whl (163 kB)
#      -------------------------------------- 163.6/163.6 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.4)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.6 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.2 pillow-9.3.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.3-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.23.4)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ------------------------------------- 298.0/298.0 kB 18.0 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
#      ---------------------------------------- 40.1/40.1 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.3 scipy-1.9.3 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      -------------------------------------- 288.2/288.2 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pgmpy
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pgmpy
#   Downloading pgmpy-0.1.20-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (1.23.4)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (1.9.3)
# Requirement already satisfied: pandas in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (1.5.1)
# Collecting opt-einsum
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB ? eta 0:00:00
# Requirement already satisfied: joblib in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (1.2.0)
# Requirement already satisfied: pyparsing in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (3.0.9)
# Collecting torch
#   Downloading torch-1.13.0-cp310-cp310-win_amd64.whl (167.3 MB)
#      -------------------------------------- 167.3/167.3 MB 6.1 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.5 MB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pgmpy) (1.1.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas->pgmpy) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->pgmpy) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from statsmodels->pgmpy) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      -------------------------------------- 233.8/233.8 kB 7.2 MB/s eta 0:00:00
# Collecting typing-extensions
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: colorama in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: six in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from patsy>=0.5.2->statsmodels->pgmpy) (1.16.0)
# Installing collected packages: typing-extensions, tqdm, patsy, opt-einsum, networkx, torch, statsmodels, pgmpy
# Successfully installed networkx-2.8.8 opt-einsum-3.3.0 patsy-0.5.3 pgmpy-0.1.20 statsmodels-0.13.5 torch-1.13.0 tqdm-4.64.1 typing-extensions-4.4.0
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install bokeh
# Out:
# Collecting bokehNote: you may need to restart the kernel to use updated packages.
#
#   Downloading bokeh-3.0.2-py3-none-any.whl (16.4 MB)
#      --------------------------------------- 16.4/16.4 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (9.3.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (6.2)
# Collecting xyzservices>=2021.09.1
#   Downloading xyzservices-2022.9.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.9/55.9 kB ? eta 0:00:00
# Requirement already satisfied: contourpy>=1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.0.6)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.23.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (1.5.1)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=16.8 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh) (21.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from packaging>=16.8->bokeh) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# Installing collected packages: xyzservices, PyYAML, bokeh
# Successfully installed PyYAML-6.0 bokeh-3.0.2 xyzservices-2022.9.0
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade bokeh==2.4.3
# Out:
# Collecting bokeh==2.4.3
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      --------------------------------------- 18.5/18.5 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.9 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (9.3.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (4.4.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (1.23.4)
# Requirement already satisfied: tornado>=5.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from bokeh==2.4.3) (6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh==2.4.3) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from packaging>=16.8->bokeh==2.4.3) (3.0.9)
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.0.2
#     Uninstalling bokeh-3.0.2:
#       Successfully uninstalled bokeh-3.0.2
# Successfully installed bokeh-2.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wittgenstein
# Out:
# Collecting wittgenstein
#   Downloading wittgenstein-0.3.2-py3-none-any.whl (124 kB)
#      -------------------------------------- 124.8/124.8 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from wittgenstein) (1.5.1)
# Requirement already satisfied: numpy in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from wittgenstein) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas->wittgenstein) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from pandas->wittgenstein) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\mscit6\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->wittgenstein) (1.16.0)
# Installing collected packages: wittgenstein
# Successfully installed wittgenstein-0.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
